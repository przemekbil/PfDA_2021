# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Intro to pyplot

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %% [markdown]
# ### Formatting the style of your plot

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# ### Plotting 2 different plots on the one axis

# %%
x = np.arange(0.0, 10.0, 0.01)
y = 3.0 * x + 1.0

# %%
noise = np.random.normal(0.0, 1.0, len(x))

# %%
plt.plot(x, y+noise, 'r.')
plt.plot(x, y, 'b-')
plt.show()

# %% [markdown]
# ### Titles, legends and labels

# %%
plt.plot(x, y+noise, 'r.', label="Actual")
plt.plot(x, y, 'b-', label="Model")


plt.title("Simple plot")
plt.xlabel("Weight")
plt.ylabel("Mass")
plt.legend()

plt.show()

# %% [markdown]
# ### Histograms

# %%
plt.hist(noise, bins=15)
# Out:
# (array([  6.,   6.,  28.,  76.,  79., 119., 165., 191., 145.,  96.,  54.,
#          21.,  11.,   1.,   2.]),
#  array([-2.95561033, -2.5286588 , -2.10170727, -1.67475574, -1.24780422,
#         -0.82085269, -0.39390116,  0.03305037,  0.4600019 ,  0.88695343,
#          1.31390496,  1.74085649,  2.16780801,  2.59475954,  3.02171107,
#          3.4486626 ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# ### Plotting side-by-side

# %%
plt.subplot(1,2,1)
x = np.random.normal(0.0, 1.0, 10000)
plt.hist(x)
plt.axis([-3.5, 3.5, 0, 3000])

plt.subplot(1,2,2)
x = np.random.uniform(-3.0, 3.0, 10000)
plt.hist(x)
plt.axis([-3.5, 3.5, 0, 3000])

plt.show()

# %% [markdown]
# ### Scatter plot

# %%
n = 100
x = np.random.uniform(0.0, 10.0, n)
y = np.random.uniform(0.0, 100.0, n)
z = np.random.normal(100, 40.0, n)
c = np.random.randint(0, 20, n)

plt.scatter(x, y, c=c, s=z)
plt.show()

# %% [markdown]
# ### Trigonometric functions

# %%
x = np.arange(-2.0 * np.pi, 2.0 * np.pi, 0.1)

plt.plot(x, np.sin(x), 'g.')
plt.plot(x, np.cos(x), 'b.')

plt.show()

# %% [markdown]
# ### Power of x

# %%
x = np.arange(0.0, 16, 0.1)

plt.plot(x, x**2, 'g-', label="x^2")
plt.plot(x, x**3, 'b-', label="x^3")
plt.plot(x, x**4, 'r-', label="x^4")
plt.plot(x, 2**x, 'k-', label="2^x")

plt.legend()
plt.show()
